# %% [markdown]
# # Sumo Wrestling Match Prediction
#
# ## Data Cleaning (2/5)

# %% [markdown]
# ## Contents:
# - [Data Import](#Data-Import)
# - [Data Cleaning](#Data-Cleaning)
#     - Handle missing values
#     - Drop `r2_win`

# %% [markdown]
# ## Data Import

# %% [markdown]
# ### Libraries

# %%
# Import libraries
import numpy as np 
import pandas as pd

from datetime import datetime

# %%
# Change the option to display with no max 
# Reference: (https://kakakakakku.hatenablog.com/entry/2021/04/19/090229)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Data Import

# %% [markdown]
# #### sumo_v1_combined.csv

# %%
# Read in the data
df = pd.read_csv('../data/sumo_v1_combined.csv')

# Review
df.head()
# Out:
#      basho  day  r1_id r1_rank    r1_shikona  r1_result  r1_win   kimarite  \
# 0  1983.01    1   4140    J13w   Chikubayama  0-1 (7-8)       0   yorikiri
# 1  1983.01    3   1337    J12w  Tochitsukasa  1-2 (9-6)       0   yorikiri
# 2  1983.01   15   4097    J12e    Tamakiyama        8-7       1   yorikiri
# 3  1983.01    2   4140    J13w   Chikubayama  1-1 (7-8)       1  oshidashi
# 4  1983.01    8   1337    J12w  Tochitsukasa  4-4 (9-6)       1  oshidashi
#
#    r2_id r2_rank r2_shikona  r2_result  r2_win    r1_heya r1_shusshin  \
# 0   4306    Ms1e      Ofuji  1-0 (6-1)       1   Miyagino     Fukuoka
# 1   4306    Ms1e      Ofuji  2-0 (6-1)       1   Kasugano       Aichi
# 2   4306    Ms1e      Ofuji        6-1       0  Kataonami     Fukuoka
# 3   4125     J7e     Shinko  0-2 (8-7)       0   Miyagino     Fukuoka
# 4   4125     J7e     Shinko  4-4 (8-7)       0   Kasugano       Aichi
#
#   r1_birth_date  r1_height  r1_weight r1_prev  r1_prev_w  r1_prev_l  \
# 0    1957-08-21      175.5      115.0    Ms4e        4.0        3.0
# 1    1958-04-25      178.5      130.0    Ms5e        5.0        2.0
# 2    1951-04-29      182.0      134.0    Ms2w        5.0        2.0
# 3    1957-08-21      175.5      115.0    Ms4e        4.0        3.0
# 4    1958-04-25      178.5      130.0    Ms5e        5.0        2.0
#
#      r2_heya r2_shusshin r2_birth_date  r2_height  r2_weight r2_prev  \
# 0    Kokonoe       Tokyo    1958-08-26      193.5      145.0    Ms4w
# 1    Kokonoe       Tokyo    1958-08-26      193.5      145.0    Ms4w
# 2    Kokonoe       Tokyo    1958-08-26      193.5      145.0    Ms4w
# 3  Isegahama    Yamagata    1950-01-02      188.0      134.0    M14w
# 4  Isegahama    Yamagata    1950-01-02      188.0      134.0    M14w
#
#    r2_prev_w  r2_prev_l
# 0        4.0        3.0
# 1        4.0        3.0
# 2        4.0        3.0
# 3        3.0       12.0
# 4        3.0       12.0

# %%
# Check data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226590 entries, 0 to 226589
# Data columns (total 29 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   basho          226590 non-null  float64
#  1   day            226590 non-null  int64
#  2   r1_id          226590 non-null  int64
#  3   r1_rank        226590 non-null  object
#  4   r1_shikona     226590 non-null  object
#  5   r1_result      226590 non-null  object
#  6   r1_win         226590 non-null  int64
#  7   kimarite       226590 non-null  object
#  8   r2_id          226590 non-null  int64
#  9   r2_rank        226590 non-null  object
#  10  r2_shikona     226590 non-null  object
#  11  r2_result      226590 non-null  object
#  12  r2_win         226590 non-null  int64
#  13  r1_heya        226590 non-null  object
#  14  r1_shusshin    226590 non-null  object
#  15  r1_birth_date  226590 non-null  object
#  16  r1_height      226559 non-null  float64
#  17  r1_weight      226559 non-null  float64
#  18  r1_prev        226590 non-null  object
#  19  r1_prev_w      226590 non-null  float64
#  20  r1_prev_l      226590 non-null  float64
#  21  r2_heya        226590 non-null  object
#  22  r2_shusshin    226590 non-null  object
#  23  r2_birth_date  226590 non-null  object
#  24  r2_height      226559 non-null  float64
#  25  r2_weight      226559 non-null  float64
#  26  r2_prev        226590 non-null  object
#  27  r2_prev_w      226590 non-null  float64
#  28  r2_prev_l      226590 non-null  float64
# dtypes: float64(9), int64(5), object(15)
# memory usage: 50.1+ MB

# %%
# Check data shape
df.shape
# Out:
# (226590, 29)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Handle missing values

# %% [markdown]
# There are some missing values for sumo wrestlers' height (h) and weight (w). These missing values come from two sumo wrestlers: Takeuchi and Miyabiyama. Takeuchi only had 1 game outcome (two data for when he's registered as r1 and r2) in the dataset and these rows were dropped. The missing values for Miyabiyama was from 1998.11 and 1999.01 basho. His information was available in 1999.03 bashowhere he had a height of 187.7 and weight of 171.0. It is worth noting that his body shape did not change until the 2000.3 basho, where his height changed to 188.0 and his weight changed to 175.5. To fill in the missing values for Miyabiyama's height and weight in 1998.11 and 1999.01 basho data, the same values from the 1999.03 basho were used.

# %%
# Check for missing values 
df.isnull().sum().sort_values(ascending=False)
# Out:
# r2_weight        31
# r2_height        31
# r1_weight        31
# r1_height        31
# basho             0
# r1_birth_date     0
# r2_prev_w         0
# r2_prev           0
# r2_birth_date     0
# r2_shusshin       0
# r2_heya           0
# r1_prev_l         0
# r1_prev_w         0
# r1_prev           0
# r1_shusshin       0
# day               0
# r1_heya           0
# r2_win            0
# r2_result         0
# r2_shikona        0
# r2_rank           0
# r2_id             0
# kimarite          0
# r1_win            0
# r1_result         0
# r1_shikona        0
# r1_rank           0
# r1_id             0
# r2_prev_l         0
# dtype: int64

# %%
# Check rows where height & weight is missing 
# This reveals that height & weight info are missing for only two rikishi: 
# Takeuchi and Miyabiyama 
df.loc[df['r1_height'].isnull()]
# Out:
#          basho  day  r1_id r1_rank  r1_shikona    r1_result  r1_win  \
# 89652  1998.09   13    842    Ms6w    Takeuchi          7-0       1
# 90425  1998.11    8    842    J11w  Miyabiyama   7-1 (12-3)       1
# 90440  1998.11    6    842    J11w  Miyabiyama   5-1 (12-3)       1
# 90485  1998.11   13    842    J11w  Miyabiyama  10-3 (12-3)       1
# 90499  1998.11    2    842    J11w  Miyabiyama   1-1 (12-3)       0
# 90514  1998.11    1    842    J11w  Miyabiyama   1-0 (12-3)       1
# 90528  1998.11   15    842    J11w  Miyabiyama         12-3       1
# 90560  1998.11    3    842    J11w  Miyabiyama   2-1 (12-3)       1
# 90591  1998.11    5    842    J11w  Miyabiyama   4-1 (12-3)       1
# 90606  1998.11   11    842    J11w  Miyabiyama   8-3 (12-3)       0
# 90620  1998.11    4    842    J11w  Miyabiyama   3-1 (12-3)       1
# 90636  1998.11   12    842    J11w  Miyabiyama   9-3 (12-3)       1
# 90651  1998.11    9    842    J11w  Miyabiyama   7-2 (12-3)       0
# 90666  1998.11   10    842    J11w  Miyabiyama   8-2 (12-3)       1
# 90680  1998.11    7    842    J11w  Miyabiyama   6-1 (12-3)       1
# 90694  1998.11   14    842    J11w  Miyabiyama  11-3 (12-3)       1
# 91378  1999.01   15    842     J1w  Miyabiyama         14-1       1
# 91393  1999.01   11    842     J1w  Miyabiyama  10-1 (14-1)       1
# 91408  1999.01   14    842     J1w  Miyabiyama  13-1 (14-1)       1
# 91502  1999.01    4    842     J1w  Miyabiyama   4-0 (14-1)       1
# 91518  1999.01   10    842     J1w  Miyabiyama   9-1 (14-1)       1
# 91531  1999.01    3    842     J1w  Miyabiyama   3-0 (14-1)       1
# 91548  1999.01    9    842     J1w  Miyabiyama   8-1 (14-1)       1
# 91623  1999.01    8    842     J1w  Miyabiyama   7-1 (14-1)       1
# 91640  1999.01    2    842     J1w  Miyabiyama   2-0 (14-1)       1
# 91656  1999.01    7    842     J1w  Miyabiyama   6-1 (14-1)       1
# 91671  1999.01    6    842     J1w  Miyabiyama   5-1 (14-1)       1
# 91745  1999.01    1    842     J1w  Miyabiyama   1-0 (14-1)       1
# 91792  1999.01   12    842     J1w  Miyabiyama  11-1 (14-1)       1
# 91806  1999.01    5    842     J1w  Miyabiyama   4-1 (14-1)       0
# 91819  1999.01   13    842     J1w  Miyabiyama  12-1 (14-1)       1
#
#           kimarite  r2_id r2_rank     r2_shikona   r2_result  r2_win  \
# 89652   yoritaoshi     68    J13w       Gokenzan   5-8 (6-9)       0
# 90425     yorikiri     30     J9w  Kitakachidoki   4-4 (8-7)       0
# 90440    oshidashi     60     J8e      Toyonoumi   4-2 (8-7)       0
# 90485    oshidashi     62     J7e         Daishi   6-7 (8-7)       0
# 90499     ketaguri     76    J10w     Hoshitango   1-1 (8-7)       1
# 90514    oshidashi     59    J12w      Susanoumi   0-1 (8-7)       0
# 90528    oshidashi     66     J6e     Wakahayato         7-8       0
# 90560     yorikiri     63     J8w       Otsukasa   1-2 (6-9)       0
# 90591  tsukiotoshi     61    J13e   Hokutohikari   2-3 (6-9)       0
# 90606     yorikiri     53     J9e    Tokitsunada   8-3 (9-6)       1
# 90620     yorikiri     51     J6w         Daizen   2-2 (7-8)       0
# 90636    oshidashi     52     J4e     Tomonohana   6-6 (8-7)       0
# 90651    oshidashi     46     J5e     Dewaarashi   5-4 (9-6)       1
# 90666     yorikiri     43     J1e     Kinkaiyama   7-3 (8-7)       0
# 90680   hatakikomi     55     J5w    Zenshinyama   4-3 (8-7)       0
# 90694   hatakikomi     54     J3e        Ohinode   7-7 (8-7)       0
# 91378    oshidashi    145    J12e           Kobo         9-6       0
# 91393    uwatenage     42    J10e       Mainoumi   7-4 (9-6)       0
# 91408    uwatenage     64     J9w      Yotsukasa   9-5 (9-6)       0
# 91502   hatakikomi     58     J4e         Oikari   1-3 (7-8)       0
# 91518   okuridashi     30     J8e  Kitakachidoki   6-4 (8-7)       0
# 91531    oshidashi     55     J3e    Zenshinyama  0-3 (4-11)       0
# 91548     yorikiri     37     J7e    Kotoinazuma  4-5 (5-10)       0
# 91623   okuridashi     60     J6w      Toyonoumi   4-4 (7-8)       0
# 91640    oshidashi     34     J2e      Asanowaka   1-1 (9-6)       0
# 91656     yorikiri     41     J6e     Kyokutenho   4-3 (9-6)       0
# 91671   oshitaoshi     32     J5e       Akinoshu   3-3 (7-8)       0
# 91745     yorikiri     54     J1e        Ohinode   0-1 (8-7)       0
# 91792    oshidashi     27    M11e       Wakanojo   5-7 (6-9)       0
# 91806   hatakikomi     21    M13e    Asahiyutaka   1-4 (4-9)       1
# 91819     yorikiri     47    M14e    Chiyotenzan  9-4 (10-5)       0
#
#            r1_heya r1_shusshin r1_birth_date  r1_height  r1_weight r1_prev  \
# 89652  Musashigawa     Ibaraki    1977-07-28        NaN        NaN  Ms60TD
# 90425  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    Ms6w
# 90440  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    Ms6w
# 90485  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    Ms6w
# 90499  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    Ms6w
# 90514  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    Ms6w
# 90528  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    Ms6w
# 90560  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    Ms6w
# 90591  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    Ms6w
# 90606  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    Ms6w
# 90620  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    Ms6w
# 90636  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    Ms6w
# 90651  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    Ms6w
# 90666  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    Ms6w
# 90680  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    Ms6w
# 90694  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    Ms6w
# 91378  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    J11w
# 91393  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    J11w
# 91408  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    J11w
# 91502  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    J11w
# 91518  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    J11w
# 91531  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    J11w
# 91548  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    J11w
# 91623  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    J11w
# 91640  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    J11w
# 91656  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    J11w
# 91671  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    J11w
# 91745  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    J11w
# 91792  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    J11w
# 91806  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    J11w
# 91819  Musashigawa     Ibaraki    1977-07-28        NaN        NaN    J11w
#
#        r1_prev_w  r1_prev_l      r2_heya r2_shusshin r2_birth_date  r2_height  \
# 89652        7.0        0.0   Futagoyama      Kagawa    1973-07-12      194.0
# 90425        7.0        0.0     Isenoumi    Hokkaido    1966-01-01      182.0
# 90440        7.0        0.0   Futagoyama     Fukuoka    1965-09-22      190.0
# 90485        7.0        0.0    Oshiogawa     Ibaraki    1968-08-23      181.0
# 90499        7.0        0.0    Michinoku   Argentina    1965-09-05      184.0
# 90514        7.0        0.0    Kitanoumi       Aichi    1972-08-30      183.0
# 90528        7.0        0.0     Miyagino   Kagoshima    1971-01-03      185.0
# 90560        7.0        0.0    Irumagawa       Hyogo    1971-02-18      176.0
# 90591        7.0        0.0      Hakkaku    Kumamoto    1972-07-15      181.0
# 90606        7.0        0.0  Tokitsukaze   Tokushima    1969-08-02      188.0
# 90620        7.0        0.0  Nishonoseki       Osaka    1964-12-14      189.0
# 90636        7.0        0.0    Tatsunami    Kumamoto    1964-06-23      175.0
# 90651        7.0        0.0    Dewanoumi    Nagasaki    1970-07-28      186.0
# 90666        7.0        0.0    Dewanoumi    Nagasaki    1976-01-07      183.0
# 90680        7.0        0.0   Takadagawa    Kanagawa    1966-04-22      179.0
# 90694        7.0        0.0    Tatsunami       Hyogo    1970-01-19      183.0
# 91378       12.0        3.0     Miyagino   Kagoshima    1973-08-18      182.5
# 91393       12.0        3.0    Dewanoumi      Aomori    1968-02-17      171.0
# 91408       12.0        3.0    Irumagawa         Mie    1973-09-25      177.0
# 91502       12.0        3.0     Isenoumi       Kyoto    1972-06-16      177.0
# 91518       12.0        3.0     Isenoumi    Hokkaido    1966-01-01      182.0
# 91531       12.0        3.0   Takadagawa    Kanagawa    1966-04-22      179.0
# 91548       12.0        3.0   Sadogatake       Gunma    1962-04-26      180.0
# 91623       12.0        3.0   Futagoyama     Fukuoka    1965-09-22      190.0
# 91640       12.0        3.0    Wakamatsu       Aichi    1969-12-11      176.0
# 91656       12.0        3.0       Oshima    Mongolia    1974-09-13      192.0
# 91671       12.0        3.0       Izutsu   Hiroshima    1969-01-17      179.0
# 91745       12.0        3.0    Tatsunami       Hyogo    1970-01-19      183.0
# 91792       12.0        3.0       Magaki     Okinawa    1973-04-13      193.0
# 91806       12.0        3.0       Oshima       Aichi    1968-09-10      190.0
# 91819       12.0        3.0      Kokonoe       Osaka    1976-02-06      183.0
#
#        r2_weight r2_prev  r2_prev_w  r2_prev_l
# 89652      192.5    Ms1e        4.0        3.0
# 90425      144.0     J7e        7.0        8.0
# 90440      225.0     J3w        6.0        9.0
# 90485      161.0     J6e        7.0        8.0
# 90499      165.5    J13e        9.0        6.0
# 90514      240.0     J3e        4.0       11.0
# 90528      161.0    J10w        9.0        6.0
# 90560      147.0    J11w        9.0        6.0
# 90591      147.0    Ms1w        5.0        2.0
# 90606      178.0     J4e        6.0        9.0
# 90620      153.0     J8w        8.0        7.0
# 90636      110.0     J9e        9.0        6.0
# 90651      186.0     J2e        6.0        9.0
# 90666      141.0     J1e        8.0        7.0
# 90680      136.0     J4w        7.0        8.0
# 90694      152.0     J6w        8.0        7.0
# 91378      126.0    Ms2w        5.0        2.0
# 91393      101.0     J1w        3.0       12.0
# 91408      151.0     J7w        7.0        8.0
# 91502      131.0    M15w        5.0       10.0
# 91518      144.0     J9w        8.0        7.0
# 91531      136.0     J5w        8.0        7.0
# 91548      137.0     J3w        6.0        9.0
# 91623      225.0     J8e        8.0        7.0
# 91640      140.0    M15e        6.0        9.0
# 91656      141.0     J2w        6.0        9.0
# 91671      117.0    M14e        4.0       11.0
# 91745      152.0     J3e        8.0        7.0
# 91792      154.0     M8e        6.0        9.0
# 91806      132.0    M10e        6.0        9.0
# 91819      149.0     J2e        9.0        6.0

# %%
# Get Takeuchi rikishi info
df.loc[(df['r1_shikona']=='Takeuchi') | (df['r2_shikona']=='Takeuchi')]
# Out:
#          basho  day  r1_id r1_rank r1_shikona  r1_result  r1_win    kimarite  \
# 89607  1998.09   13     68    J13w   Gokenzan  5-8 (6-9)       0  yoritaoshi
# 89652  1998.09   13    842    Ms6w   Takeuchi        7-0       1  yoritaoshi
#
#        r2_id r2_rank r2_shikona  r2_result  r2_win      r1_heya r1_shusshin  \
# 89607    842    Ms6w   Takeuchi        7-0       1   Futagoyama      Kagawa
# 89652     68    J13w   Gokenzan  5-8 (6-9)       0  Musashigawa     Ibaraki
#
#       r1_birth_date  r1_height  r1_weight r1_prev  r1_prev_w  r1_prev_l  \
# 89607    1973-07-12      194.0      192.5    Ms1e        4.0        3.0
# 89652    1977-07-28        NaN        NaN  Ms60TD        7.0        0.0
#
#            r2_heya r2_shusshin r2_birth_date  r2_height  r2_weight r2_prev  \
# 89607  Musashigawa     Ibaraki    1977-07-28        NaN        NaN  Ms60TD
# 89652   Futagoyama      Kagawa    1973-07-12      194.0      192.5    Ms1e
#
#        r2_prev_w  r2_prev_l
# 89607        7.0        0.0
# 89652        4.0        3.0

# %%
# There are no historical info about Takeuchi. Drop this column. 
select_rows = df.index[(df['r1_shikona'] == 'Takeuchi') | (df['r2_shikona'] == 'Takeuchi')]
df.drop(select_rows, inplace=True)

# %%
# Get Miyabiyama rikishi info
df.loc[(df['r1_shikona']=='Miyabiyama') & (df['r1_height'].notnull())].head()
# Out:
#          basho  day  r1_id r1_rank  r1_shikona  r1_result  r1_win  \
# 92749  1999.03   10    842     M7e  Miyabiyama  8-2 (9-6)       1
# 92793  1999.03    8    842     M7e  Miyabiyama  6-2 (9-6)       1
# 92823  1999.03    6    842     M7e  Miyabiyama  4-2 (9-6)       1
# 92854  1999.03   14    842     M7e  Miyabiyama  9-5 (9-6)       1
# 92880  1999.03    4    842     M7e  Miyabiyama  3-1 (9-6)       1
#
#           kimarite  r2_id r2_rank   r2_shikona  r2_result  r2_win  \
# 92749   oshitaoshi     40    M12w        Kaiho  6-4 (8-7)       0
# 92793     yorikiri     54    M13w      Ohinode  6-2 (9-6)       0
# 92823  tsukitaoshi     50    M11w   Tokitsuumi  3-3 (9-6)       0
# 92854     yorikiri     23     M8w  Tochinowaka  8-6 (8-7)       0
# 92880   hatakikomi     11     M8e     Aogiyama  2-2 (8-7)       0
#
#            r1_heya r1_shusshin r1_birth_date  r1_height  r1_weight r1_prev  \
# 92749  Musashigawa     Ibaraki    1977-07-28      187.7      171.0     J1w
# 92793  Musashigawa     Ibaraki    1977-07-28      187.7      171.0     J1w
# 92823  Musashigawa     Ibaraki    1977-07-28      187.7      171.0     J1w
# 92854  Musashigawa     Ibaraki    1977-07-28      187.7      171.0     J1w
# 92880  Musashigawa     Ibaraki    1977-07-28      187.7      171.0     J1w
#
#        r1_prev_w  r1_prev_l      r2_heya r2_shusshin r2_birth_date  r2_height  \
# 92749       14.0        1.0      Hakkaku      Aomori    1973-04-17      178.0
# 92793       14.0        1.0    Tatsunami       Hyogo    1970-01-19      184.0
# 92823       14.0        1.0  Tokitsukaze    Nagasaki    1973-11-08      184.0
# 92854       14.0        1.0     Kasugano    Wakayama    1962-05-22      190.0
# 92880       14.0        1.0  Tokitsukaze       Shiga    1970-02-18      181.5
#
#        r2_weight r2_prev  r2_prev_w  r2_prev_l
# 92749      122.0     M9w        6.0        9.0
# 92793      151.5     J1e        8.0        7.0
# 92823      127.0     M5e        4.0       11.0
# 92854      154.5     M6e        6.0        9.0
# 92880      153.0     M3w        4.0       11.0

# %%
# His height and weight info was missing in 1998.11 and 1999.01 basho.
# However, his info was available in 1999.03 basho and it was h=187.7 & w=171.0. 
# His body shape did not change till 2000.03 basho (changed to h=188.0 & w=175.5).
# Fill the missing values in 1998.11 and 1999.01 basho same as info in 1999.03 basho. 

# Fill missing values in 'rikishi1_height' and 'rikishi2_height' with 187.7
df.loc[df['r1_height'].isnull(), 'r1_height'] = 187.7
df.loc[df['r2_height'].isnull(), 'r2_height'] = 187.7

# Fill missing values in 'rikishi1_weight' and 'rikishi2_weight' with 171.0
df.loc[df['r1_weight'].isnull(), 'r1_weight'] = 171.0
df.loc[df['r2_weight'].isnull(), 'r2_weight'] = 171.0

# %%
# Review the missing values again 
df.isnull().sum()
# Out:
# basho            0
# day              0
# r1_id            0
# r1_rank          0
# r1_shikona       0
# r1_result        0
# r1_win           0
# kimarite         0
# r2_id            0
# r2_rank          0
# r2_shikona       0
# r2_result        0
# r2_win           0
# r1_heya          0
# r1_shusshin      0
# r1_birth_date    0
# r1_height        0
# r1_weight        0
# r1_prev          0
# r1_prev_w        0
# r1_prev_l        0
# r2_heya          0
# r2_shusshin      0
# r2_birth_date    0
# r2_height        0
# r2_weight        0
# r2_prev          0
# r2_prev_w        0
# r2_prev_l        0
# dtype: int64

# %% [markdown]
# ### Drop unnecessary columns

# %% [markdown]
# `r2_win` was excluded from the dataset as it contains redundant information with `r1_win`, which is the target variable for the model. When `r1_win` is equal to a value of `1` or win, `r2_win` is automatically set to `0` or lose. Including `r2_win` in the modeling process would lead to multicollinearity and adversely affect the model's performance."

# %%
# Drop duplicates columns - same as target variable 'r1_win'
df.drop(columns = ['r2_win'], inplace=True)

# %% [markdown]
# ### Save clean dataframe as csv file

# %% [markdown]
# The clean dataset was saved to a csv file for next step

# %%
# Save dataset in csv file 
df.to_csv('../data/sumo_v2_clean.csv', index=False)
